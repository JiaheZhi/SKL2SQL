# %%
import pandas as pd

# %%
df = pd.read_csv('/root/volume/SKL2SQL/dataset/US_Accidents_March23_train.csv')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           ID   Source           Start_Time             End_Time  Start_Lat  \
# 0  A-1290474  Source2  2020-09-08 20:23:48  2020-09-08 21:27:21  32.791885
# 1  A-4189259  Source1  2023-01-20 22:02:00  2023-01-20 22:25:00  34.154531
# 2   A-772230  Source2  2021-12-20 14:36:18  2021-12-20 15:05:48  39.213181
# 3  A-1302628  Source2  2020-09-17 16:01:59  2020-09-17 16:31:40  33.980827
# 4  A-7343045  Source1  2019-10-16 15:59:00  2019-10-16 16:51:33  37.679347
#
#     Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0  -96.729141        NaN         NaN         0.000
# 1 -118.392175  34.156606 -118.403296         0.652
# 2  -84.454041        NaN         NaN         0.000
# 3  -81.106888        NaN         NaN         0.000
# 4 -122.126826  37.679347 -122.126826         0.000
#
#                                          Description         Street  \
# 0  #4 lane blocked due to accident on I-30 Westbo...         I-30 E
# ...

# %%
df.to_csv('/root/volume/SKL2SQL/dataset/US_Accidents_March23_test.csv', na_rep='NULL', index=False, header=False)

# %%
df[:100].to_csv('/root/volume/SKL2SQL/dataset/US_Accidents_March23_test_head_100_rows.csv', na_rep='NULL', index=False, header=False)

# %%
for i in range(len(df)):
    if not pd.isna(df.at[i, 'Description']) and df.at[i, 'Description'][-1] == '\\':
        df.at[i, 'Description'] += ' '
